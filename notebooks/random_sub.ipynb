# %%
import pandas as pd
import numpy as np
import random

test_labels = ['yes', 'no','up', 'down', 'left', 'right', 'on', 'off', 'stop', 'go', 'silence', 'unknown']
sub = pd.read_csv('/home/tony/Downloads/sample_submission.csv')
sub['label'] = [random.choice(test_labels) for i in np.arange(len(sub))]
sub.to_csv('random_sub.csv', index = False)

# %%
sub
# Out:
#                      fname    label
# 0       clip_000044442.wav  unknown
# 1       clip_0000adecb.wav       go
# 2       clip_0000d4322.wav       no
# 3       clip_0000fb6fe.wav       no
# 4       clip_0001d1559.wav       on
# 5       clip_0002256ed.wav       up
# 6       clip_0002a4a1f.wav     down
# 7       clip_0002d9b83.wav     down
# 8       clip_000373a5b.wav       on
# 9       clip_0003c7122.wav      yes
# 10      clip_0003e6aee.wav      yes
# 11      clip_00049951d.wav       go
# 12      clip_0004c6707.wav     stop
# 13      clip_0004f8b63.wav     left
# 14      clip_00068e281.wav     down
# 15      clip_00069e9cb.wav       no
# 16      clip_0006f7b8b.wav     stop
# 17      clip_0007ec7e6.wav      yes
# 18      clip_00082a7d6.wav       no
# 19      clip_00094eb22.wav      off
# 20      clip_000962cbb.wav    right
# 21      clip_000a96d0a.wav      yes
# 22      clip_000b01093.wav      off
# 23      clip_000b378f1.wav     down
# 24      clip_000b9514b.wav    right
# ...
